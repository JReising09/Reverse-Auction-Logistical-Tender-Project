# %%
#Import of main libraries 
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np 
from __future__ import division, print_function
from pandas import read_excel
from pandas import DataFrame
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
#Import of the pyomo module
from pyomo.environ import *
#Creation of a Concrete Model
model = ConcreteModel()

# %%
BidsDf = read_excel('Logistics Tendering Data for CaseStudy PIC2018.xlsx', sheet_name='Bids')

# %%
LanesDf = read_excel('Logistics Tendering Data for CaseStudy PIC2018.xlsx', sheet_name='Lots')
LanesDf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Lot</th>
#       <th>Lot#</th>
#       <th># Shipments</th>
#       <th>AsIs Cost/Shipment</th>
#       <th>Spend AsIs</th>
#       <th>Lot Type</th>
#       <th>Site From</th>
#       <th>Site Cluster</th>
#       <th>Country To</th>
#       <th>Country Cluster</th>
#       <th>Incumbent</th>
#       <th>Lowest Bid</th>
#       <th>Avg Bid</th>
#       <th>Max Quote</th>
#       <th># Bids</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ISO_001</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2686.8</td>
#       <td>8060.4</td>
#       <td>Long Tail</td>
#       <td>BK</td>
#       <td>Benelux</td>
#       <td>MX</td>
#       <td>Mexico</td>
#       <td>VTGT</td>
#       <td>2864.4</td>
#       <td>4313.127273</td>
#       <td>6074.4</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ISO_002</td>
#       <td>2</td>
#       <td>3</td>
#       <td>2362.8</td>
#       <td>7088.4</td>
#       <td>Long Tail</td>
#       <td>BK</td>
#       <td>Benelux</td>
#       <td>MX</td>
#       <td>Mexico</td>
#       <td>INTT</td>
#       <td>2337.6</td>
#       <td>3478.690909</td>
#       <td>4942.8</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ISO_003</td>
#       <td>3</td>
#       <td>2</td>
#       <td>3092.4</td>
#       <td>6184.8</td>
#       <td>Long Tail</td>
#       <td>BK</td>
#       <td>Benelux</td>
#       <td>TR</td>
#       <td>Mediterranean</td>
#       <td>MSLO</td>
#       <td>2456.4</td>
#       <td>3809.550000</td>
#       <td>5070.0</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ISO_004</td>
#       <td>4</td>
#       <td>1</td>
#       <td>2755.2</td>
#       <td>2755.2</td>
#       <td>Long Tail</td>
#       <td>BK</td>
#       <td>Benelux</td>
#       <td>IL</td>
#       <td>Mediterranean</td>
#       <td>MSLO</td>
#       <td>2214.0</td>
#       <td>2856.720000</td>
#       <td>3540.0</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ISO_005</td>
#       <td>5</td>
#       <td>6</td>
#       <td>2624.4</td>
#       <td>15746.4</td>
#       <td>Focus</td>
#       <td>BK</td>
#       <td>Benelux</td>
#       <td>IL</td>
#       <td>Mediterranean</td>
#       <td>BLKH</td>
#       <td>2143.2</td>
#       <td>3157.600000</td>
#       <td>4057.2</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
LanesDf.loc[BidsDf.loc[0,'Lot#'],'Incumbent'] #How to locate incumbent for a lane
# Out:
# 'INTT'

# %%
#Create a vector indicating the bid number in which the incumbent placed a bid (Note the sum should be = the total number of lanes 234)
IncumbentVector = np.zeros(len(BidsDf.index))

for i in BidsDf.index:
    if BidsDf.loc[i,'Carrier'] == LanesDf.loc[BidsDf.loc[i,'Lot#']-1,'Incumbent']:
        IncumbentVector[i] = 1
    else:
        IncumbentVector[i] = 0

# %%
#Create the data frame for Incumbents
IncumbentDf = DataFrame(IncumbentVector)
IncumbentDf.columns = ['IncumbentBid']

# %%
gammaDf = DataFrame(np.zeros((len(LanesDf.index), len(BidsDf.index))))

for i in BidsDf.index:
    gammaDf.at[BidsDf.loc[i,'Lot#'] - 1, i] = IncumbentDf.loc[i]

# %%
#Number of bids in the program
model.numBids = len(BidsDf.index)
#Number of lanes in the program
model.numItems = len(LanesDf.index)

# %%
## Define sets
model.BIDS = Set(initialize = BidsDf.index.values)
model.LANES = Set(initialize = LanesDf.index.values)

# %%
# Create a dictionary of the bid values
bidValues = dict()
for bid in BidsDf.index:
    bidValues[bid] = BidsDf.loc[bid, 'Cost']
#bidValues
# Out:
# {0: 2864.4,
#  1: 2970.0,
#  2: 3225.6,
#  3: 3499.2,
#  4: 3915.6,
#  5: 4128.0,
#  6: 4166.4,
#  7: 5336.4,
#  8: 5528.4,
#  9: 5736.0,
#  10: 6074.4,
#  11: 2337.6,
#  12: 2515.2,
#  13: 2596.7999999999997,
#  14: 2733.6,
#  15: 3210.0,
#  16: 3270.0,
#  17: 3471.6,
#  18: 4138.8,
#  19: 4314.0,
#  20: 4735.2,
#  21: 4942.8,
#  22: 2456.4,
#  23: 3270.0,
#  24: 3462.0,
#  25: 3558.0,
#  26: 3960.0,
#  27: 4260.0,
#  28: 4440.0,
#  29: 5070.0,
#  30: 2214.0,
#  31: 2838.0,
#  32: 2842.7999999999997,
#  33: 2848.7999999999997,
#  34: 3540.0,
#  35: 2143.2,
#  36: 2378.4,
#  37: 2720.4,
#  38: 2842.7999999999997,
#  39: 2958.0,
#  40: 3007.2,
#  41: 3264.0,
#  42: 3445.2,
#  43: 3642.0,
#  44: 3714.0,
#  45: 3718.7999999999997,
#  46: 4057.2,
#  47: 2718.0,
#  48: 2720.4,
#  49: 2816.4,
#  50: 2958.0,
#  51: 3013.2,
#  52: 3445.2,
#  53: 3642.0,
#  54: 3714.0,
#  55: 3718.7999999999997,
#  56: 3723.6,
#  57: 3991.2,
#  58: 4713.599999999999,
#  59: 2378.4,
#  60: 2720.4,
#  61: 2914.7999999999997,
#  62: 2958.0,
#  63: 3188.4,
#  64: 3264.0,
#  65: 3280.7999999999997,
#  66: 3445.2,
#  67: 3554.4,
#  68: 3718.7999999999997,
#  69: 3780.0,
#  70: 4057.2,
#  71: 2589.6,
#  72: 2612.4,
#  73: 3050.4,
#  74: 3056.4,
#  75: 3062.4,
#  76: 3171.6,
#  77: 3274.7999999999997,
#  78: 3510.0,
#  79: 3619.2,
#  80: 3674.4,
#  81: 3718.7999999999997,
#  82: 3915.6,
#  83: 2100.0,
#  84: 2220.0,
#  85: 2340.0,
#  86: 2430.0,
#  87: 2442.0,
#  88: 2820.0,
#  89: 3300.0,
#  90: 3396.0,
#  91: 3474.0,
#  92: 3510.0,
#  93: 3660.0,
#  94: 2040.0,
#  95: 2100.0,
#  96: 2322.0,
#  97: 2323.2,
#  98: 2700.0,
#  99: 2724.0,
#  100: 3318.0,
#  101: 3360.0,
#  102: 3540.0,
#  103: 3816.0,
#  104: 3900.0,
#  105: 960.0,
#  106: 960.0,
#  107: 1050.0,
#  108: 1392.0,
#  109: 1476.0,
#  110: 1530.0,
#  111: 1536.0,
#  112: 1800.0,
#  113: 900.0,
#  114: 960.0,
#  115: 960.0,
#  116: 990.0,
#  117: 1110.0,
#  118: 1314.0,
#  119: 1320.0,
#  120: 1390.8,
#  121: 1410.0,
#  122: 1620.0,
#  123: 1744.8,
#  124: 1800.0,
#  125: 1896.0,
#  126: 3000.0,
#  127: 2280.0,
#  128: 3036.0,
#  129: 3282.0,
#  130: 3330.0,
#  131: 3360.0,
#  132: 3396.0,
#  133: 3816.0,
#  134: 4626.0,
#  135: 5034.0,
#  136: 3636.0,
#  137: 3715.2,
#  138: 3840.0,
#  139: 4128.0,
#  140: 4290.0,
#  141: 4314.0,
#  142: 4536.0,
#  143: 4620.0,
#  144: 2400.0,
#  145: 2785.2,
#  146: 3510.0,
#  147: 3552.0,
#  148: 3714.0,
#  149: 4044.0,
#  150: 4074.0,
#  151: 4278.0,
#  152: 5088.0,
#  153: 2625.6,
#  154: 2652.0,
#  155: 2700.0,
#  156: 2916.0,
#  157: 3312.0,
#  158: 3444.0,
#  159: 3780.0,
#  160: 4106.4,
#  161: 5064.0,
#  162: 5490.0,
#  163: 2252.4,
#  164: 2570.4,
#  165: 2655.6,
#  166: 2842.7999999999997,
#  167: 2941.2,
#  168: 3007.2,
#  169: 3028.7999999999997,
#  170: 3336.0,
#  171: 3390.0,
#  172: 3510.0,
#  173: 3937.2,
#  174: 4046.3999999999996,
#  175: 2655.6,
#  176: 2707.2,
#  177: 2925.6,
#  178: 2941.2,
#  179: 3013.2,
#  180: 3271.2,
#  181: 3390.0,
#  182: 3488.4,
#  183: 3510.0,
#  184: 3991.2,
#  185: 4046.3999999999996,
#  186: 4538.4,
#  187: 1120.8,
#  188: 1148.3999999999999,
#  189: 1509.6,
#  190: 1749.6,
#  191: 1831.2,
#  192: 1924.8,
#  193: 919.1999999999999,
#  194: 956.4,
#  195: 1039.2,
#  196: 1050.0,
#  197: 1071.6,
#  198: 1230.0,
#  199: 1306.8,
#  200: 1477.2,
#  201: 1531.2,
#  202: 1711.2,
#  203: 1820.3999999999999,
#  204: 1831.2,
#  205: 1831.2,
#  206: 1858.8,
#  207: 902.4,
#  208: 940.8,
#  209: 1022.4,
#  210: 1050.0,
#  211: 1120.8,
#  212: 1148.3999999999999,
#  213: 1257.6,
#  214: 1418.3999999999999,
#  215: 1558.8,
#  216: 1585.2,
#  217: 1711.2,
#  218: 1749.6,
#  219: 1766.3999999999999,
#  220: 1831.2,
#  221: 902.4,
#  222: 940.8,
#  223: 1120.8,
#  224: 1148.3999999999999,
#  225: 1306.8,
#  226: 1418.3999999999999,
#  227: 1509.6,
#  228: 1711.2,
#  229: 1749.6,
#  230: 1777.2,
#  231: 1831.2,
#  232: 1464.0,
#  233: 1500.0,
#  234: 1560.0,
#  235: 1632.0,
#  236: 1644.0,
#  237: 1858.8,
#  238: 1974.0,
#  239: 2010.0,
#  240: 2130.0,
#  241: 2220.0,
#  242: 2400.0,
#  243: 2739.6,
#  244: 2810.4,
#  245: 3912.0,
#  246: 3250.7999999999997,
#  247: 3264.0,
#  248: 3600.0,
#  249: 3870.0,
#  250: 1728.0,
#  251: 1740.0,
#  252: 1764.0,
#  253: 2076.0,
#  254: 2160.0,
#  255: 2574.0,
#  256: 3060.0,
#  257: 2820.0,
#  258: 2928.0,
#  259: 2976.0,
#  260: 3183.6,
#  261: 3828.0,
#  262: 3972.0,
#  263: 3996.0,
#  264: 4422.0,
#  265: 4620.0,
#  266: 4830.0,
#  267: 990.0,
#  268: 1080.0,
#  269: 1486.8,
#  270: 1500.0,
#  271: 1680.0,
#  272: 2130.0,
#  273: 2553.6,
#  274: 2610.0,
#  275: 2610.0,
#  276: 2736.0,
#  277: 2952.0,
#  278: 3480.0,
#  279: 3481.2,
#  280: 1148.3999999999999,
#  281: 1388.3999999999999,
#  282: 1602.0,
#  283: 1657.2,
#  284: 1722.0,
#  285: 1749.6,
#  286: 1749.6,
#  287: 1886.3999999999999,
#  288: 1968.0,
#  289: 1974.0,
#  290: 2022.0,
#  291: 2181.6,
#  292: 2799.6,
#  293: 1852.8,
#  294: 1990.8,
#  295: 2061.6,
#  296: 2150.4,
#  297: 2460.0,
#  298: 2570.4,
#  299: 2624.4,
#  300: 2641.2,
#  301: 2673.6,
#  302: 3280.7999999999997,
#  303: 3471.6,
#  304: 4461.599999999999,
#  305: 1260.0,
#  306: 1356.0,
#  307: 1705.2,
#  308: 1726.8,
#  309: 1830.0,
#  310: 2088.0,
#  311: 2124.0,
#  312: 2154.0,
#  313: 2220.0,
#  314: 2250.0,
#  315: 2376.0,
#  316: 2460.0,
#  317: 2526.0,
#  318: 2754.0,
#  319: 1320.0,
#  320: 1356.0,
#  321: 1705.2,
#  322: 1726.8,
#  323: 1830.0,
#  324: 2088.0,
#  325: 2124.0,
#  326: 2154.0,
#  327: 2220.0,
#  328: 2250.0,
#  329: 2376.0,
#  330: 2460.0,
#  331: 2532.0,
#  332: 2754.0,
#  333: 1320.0,
#  334: 1416.0,
#  335: 1705.2,
#  336: 1726.8,
#  337: 1830.0,
#  338: 2088.0,
#  339: 2124.0,
#  340: 2250.0,
#  341: 2376.0,
#  342: 2394.0,
#  343: 2460.0,
#  344: 2596.7999999999997,
#  345: 3174.0,
#  346: 3756.0,
#  347: 1452.0,
#  348: 1470.0,
#  349: 1800.0,
#  350: 1980.0,
#  351: 2322.0,
#  352: 2640.0,
#  353: 2658.0,
#  354: 2820.0,
#  355: 2892.0,
#  356: 3108.0,
#  357: 3120.0,
#  358: 3691.2,
#  359: 2214.0,
#  360: 2264.4,
#  361: 2340.0,
#  362: 2400.0,
#  363: 2598.0,
#  364: 2820.0,
#  365: 2940.0,
#  366: 3036.0,
#  367: 3288.0,
#  368: 3444.0,
#  369: 2264.4,
#  370: 2340.0,
#  371: 2340.0,
#  372: 2400.0,
#  373: 2880.0,
#  374: 3138.0,
#  375: 3288.0,
#  376: 3468.0,
#  377: 3504.0,
#  378: 3552.0,
#  379: 3480.0,
#  380: 3678.0,
#  381: 3732.0,
#  382: 4034.3999999999996,
#  383: 4050.0,
#  384: 4080.0,
#  385: 4260.0,
#  386: 4644.0,
#  387: 7500.0,
#  388: 2400.0,
#  389: 2528.4,
#  390: 2700.0,
#  391: 2994.0,
#  392: 3000.0,
#  393: 3168.0,
#  394: 3552.0,
#  395: 4260.0,
#  396: 4530.0,
#  397: 5052.0,
#  398: 2280.0,
#  399: 2344.7999999999997,
#  400: 2544.0,
#  401: 2646.0,
#  402: 2700.0,
#  403: 2820.0,
#  404: 3216.0,
#  405: 3294.0,
#  406: 3864.0,
#  407: 4722.0,
#  408: 2040.0,
#  409: 2040.0,
#  410: 2166.0,
#  411: 2198.4,
#  412: 2430.0,
#  413: 2808.0,
#  414: 2892.0,
#  415: 2977.2,
#  416: 3240.0,
#  417: 1440.0,
#  418: 2130.0,
#  419: 2130.0,
#  420: 2160.0,
#  421: 2280.0,
#  422: 2304.0,
#  423: 2430.0,
#  424: 2691.6,
#  425: 3330.0,
#  426: 3378.0,
#  427: 1620.0,
#  428: 1836.0,
#  429: 1854.0,
#  430: 1988.3999999999999,
#  431: 2040.0,
#  432: 2160.0,
#  433: 2250.0,
#  434: 2592.0,
#  435: 2928.0,
#  436: 3054.0,
#  437: 1980.0,
#  438: 2054.4,
#  439: 2142.0,
#  440: 2160.0,
#  441: 2220.0,
#  442: 2370.0,
#  443: 2592.0,
#  444: 2874.0,
#  445: 3198.0,
#  446: 3360.0,
#  447: 3552.0,
#  448: 1740.0,
#  449: 1914.0,
#  450: 1932.0,
#  451: 2158.7999999999997,
#  452: 2296.7999999999997,
#  453: 2373.6,
#  454: 2416.7999999999997,
#  455: 2515.2,
#  456: 2589.6,
#  457: 2761.2,
#  458: 2816.4,
#  459: 2930.4,
#  460: 3007.2,
#  461: 4341.599999999999,
#  462: 6490.8,
#  463: 6676.8,
#  464: 690.0,
#  465: 870.0,
#  466: 913.1999999999999,
#  467: 1056.0,
#  468: 1092.0,
#  469: 1093.2,
#  470: 1200.0,
#  471: 1266.0,
#  472: 1302.0,
#  473: 1320.0,
#  474: 1410.0,
#  475: 1470.0,
#  476: 1800.0,
#  477: 1950.0,
#  478: 2988.0,
#  479: 1800.0,
#  480: 1830.0,
#  481: 1914.0,
#  482: 2304.0,
#  483: 2310.0,
#  484: 2355.6,
#  485: 2679.6,
#  486: 3180.0,
#  487: 3240.0,
#  488: 3656.4,
#  489: 3660.0,
#  490: 3954.0,
#  491: 5568.0,
#  492: 780.0,
#  493: 798.0,
#  494: 828.0,
#  495: 890.4,
#  496: 960.0,
#  497: 996.0,
#  498: 996.0,
#  499: 1020.0,
#  500: 1056.0,
#  501: 1080.0,
#  502: 1296.0,
#  503: 1380.0,
#  504: 1410.0,
#  505: 1590.0,
#  506: 1800.0,
#  507: 1080.0,
#  508: 1308.0,
#  509: 1320.0,
#  510: 1411.2,
#  511: 1431.6,
#  512: 1512.0,
#  513: 1668.0,
#  514: 1680.0,
#  515: 1770.0,
#  516: 1830.0,
#  517: 1884.0,
#  518: 2078.4,
#  519: 2100.0,
#  520: 2130.0,
#  521: 2388.0,
#  522: 780.0,
#  523: 780.0,
#  524: 840.0,
#  525: 955.1999999999999,
#  526: 960.0,
#  527: 1050.0,
#  528: 1094.3999999999999,
#  529: 1170.0,
#  530: 1200.0,
#  531: 1218.0,
#  532: 1278.0,
#  533: 1308.0,
#  534: 1650.0,
#  535: 1680.0,
#  536: 2268.0,
#  537: 1080.0,
#  538: 1140.0,
#  539: 1276.8,
#  540: 1320.0,
#  541: 1347.6,
#  542: 1368.0,
#  543: 1464.0,
#  544: 1560.0,
#  545: 1614.0,
#  546: 1680.0,
#  547: 1752.0,
#  548: 1815.6,
#  549: 1830.0,
#  550: 1950.0,
#  551: 1950.0,
#  552: 1470.0,
#  553: 1632.0,
#  554: 1710.0,
#  555: 1836.0,
#  556: 1986.0,
#  557: 2094.0,
#  558: 2160.0,
#  559: 2209.2,
#  560: 2400.0,
#  561: 2940.0,
#  562: 3122.4,
#  563: 3204.0,
#  564: 1020.0,
#  565: 1080.0,
#  566: 1500.0,
#  567: 1863.6,
#  568: 1884.0,
#  569: 2214.0,
#  570: 2340.0,
#  571: 2460.0,
#  572: 2994.0,
#  573: 3120.0,
#  574: 3147.6,
#  575: 3198.0,
#  576: 4752.0,
#  577: 4530.0,
#  578: 4800.0,
#  579: 5448.0,
#  580: 2157.6,
#  581: 2350.7999999999997,
#  582: 2406.0,
#  583: 2536.7999999999997,
#  584: 2624.4,
#  585: 2925.6,
#  586: 3346.7999999999997,
#  587: 3805.2,
#  588: 4166.4,
#  589: 4680.0,
#  590: 4812.0,
#  591: 7594.799999999999,
#  592: 7928.4,
#  593: 7980.0,
#  594: 8722.8,
#  595: 8904.0,
#  596: 900.0,
#  597: 900.0,
#  598: 1140.0,
#  599: 1204.8,
#  600: 1302.0,
#  601: 1308.0,
#  602: 1560.0,
#  603: 1572.0,
#  604: 1682.3999999999999,
#  605: 1740.0,
#  606: 1800.0,
#  607: 1820.3999999999999,
#  608: 2400.0,
#  609: 3900.0,
#  610: 3926.3999999999996,
#  611: 4136.4,
#  612: 4210.8,
#  613: 4702.8,
#  614: 4755.599999999999,
#  615: 5118.0,
#  616: 5238.0,
#  617: 5334.0,
#  618: 5631.599999999999,
#  619: 5790.0,
#  620: 3232.7999999999997,
#  621: 3619.2,
#  622: 3685.2,
#  623: 3717.6,
#  624: 4155.599999999999,
#  625: 4264.8,
#  626: 4888.8,
#  627: 5342.4,
#  628: 5359.2,
#  629: 5616.0,
#  630: 2220.0,
#  631: 2286.0,
#  632: 2964.0,
#  633: 3084.0,
#  634: 3130.7999999999997,
#  635: 3414.0,
#  636: 3474.0,
#  637: 4056.0,
#  638: 4735.2,
#  639: 2802.0,
#  640: 2976.0,
#  641: 3024.0,
#  642: 3343.2,
#  643: 3486.0,
#  644: 3660.0,
#  645: 3798.0,
#  646: 4630.8,
#  647: 4704.0,
#  648: 2844.0,
#  649: 2976.0,
#  650: 3024.0,
#  651: 3546.0,
#  652: 3664.7999999999997,
#  653: 3756.0,
#  654: 3888.0,
#  655: 4894.8,
#  656: 5112.0,
#  657: 1380.0,
#  658: 1440.0,
#  659: 1638.0,
#  660: 1662.0,
#  661: 1740.0,
#  662: 1992.0,
#  663: 2394.0,
#  664: 2422.7999999999997,
#  665: 2617.2,
#  666: 2688.0,
#  667: 2688.0,
#  668: 1306.8,
#  669: 1320.0,
#  670: 1344.0,
#  671: 1434.0,
#  672: 1464.0,
#  673: 1716.0,
#  674: 1804.8,
#  675: 1830.0,
#  676: 1992.0,
#  677: 1992.0,
#  678: 2322.0,
#  679: 2616.0,
#  680: 4226.4,
#  681: 4483.2,
#  682: 4501.2,
#  683: 4527.599999999999,
#  684: 4532.4,
#  685: 4647.599999999999,
#  686: 6206.4,
#  687: 7119.599999999999,
#  688: 1680.0,
#  689: 1902.0,
#  690: 2244.0,
#  691: 2268.0,
#  692: 2340.0,
#  693: 2436.0,
#  694: 2437.2,
#  695: 2712.0,
#  696: 3060.0,
#  697: 3240.0,
#  698: 3318.0,
#  699: 1246.8,
#  700: 1260.0,
#  701: 1338.0,
#  702: 1350.0,
#  703: 1368.0,
#  704: 1464.0,
#  705: 1776.0,
#  706: 1890.0,
#  707: 1950.0,
#  708: 1980.0,
#  709: 2169.6,
#  710: 2172.0,
#  711: 2820.0,
#  712: 3366.0,
#  713: 3618.0,
#  714: 4236.0,
#  715: 4308.0,
#  716: 2256.0,
#  717: 2274.0,
#  718: 2370.0,
#  719: 2386.7999999999997,
#  720: 3240.0,
#  721: 3750.0,
#  722: 2214.0,
#  723: 2859.6,
#  724: 2870.4,
#  725: 3133.2,
#  726: 2476.7999999999997,
#  727: 3156.0,
#  728: 3163.2,
#  729: 3193.2,
#  730: 3718.7999999999997,
#  731: 3734.3999999999996,
#  732: 3854.3999999999996,
#  733: 4183.2,
#  734: 4429.2,
#  735: 4440.0,
#  736: 2596.7999999999997,
#  737: 2920.7999999999997,
#  738: 3116.4,
#  739: 3154.7999999999997,
#  740: 3440.4,
#  741: 3499.2,
#  742: 3526.7999999999997,
#  743: 3691.2,
#  744: 3734.3999999999996,
#  745: 3991.2,
#  746: 4020.0,
#  747: 4166.4,
#  748: 1776.0,
#  749: 1875.6,
#  750: 1878.0,
#  751: 2040.0,
#  752: 2040.0,
#  753: 2150.4,
#  754: 2509.2,
#  755: 2952.0,
#  756: 2952.0,
#  757: 3270.0,
#  758: 3600.0,
#  759: 3397.2,
#  760: 3570.0,
#  761: 4110.0,
#  762: 4308.0,
#  763: 4992.0,
#  764: 5028.0,
#  765: 5298.0,
#  766: 5328.0,
#  767: 5460.0,
#  768: 4914.0,
#  769: 5580.0,
#  770: 5730.0,
#  771: 7128.0,
#  772: 2280.0,
#  773: 2280.0,
#  774: 2424.0,
#  775: 2625.6,
#  776: 2634.0,
#  777: 2964.0,
#  778: 3582.0,
#  779: 4020.0,
#  780: 4236.0,
#  781: 4710.0,
#  782: 2160.0,
#  783: 2280.0,
#  784: 2304.0,
#  785: 2526.0,
#  786: 2532.0,
#  787: 3384.0,
#  788: 3924.0,
#  789: 4128.0,
#  790: 4272.0,
#  791: 4320.0,
#  792: 900.0,
#  793: 960.0,
#  794: 960.0,
#  795: 1056.0,
#  796: 1080.0,
#  797: 1218.0,
#  798: 1320.0,
#  799: 1350.0,
#  800: 1360.8,
#  801: 1428.0,
#  802: 1434.0,
#  803: 1500.0,
#  804: 1634.3999999999999,
#  805: 1652.3999999999999,
#  806: 900.0,
#  807: 960.0,
#  808: 1080.0,
#  809: 1260.0,
#  810: 1428.0,
#  811: 1500.0,
#  812: 1506.0,
#  813: 1194.0,
#  814: 1296.0,
#  815: 1392.0,
#  816: 1560.0,
#  817: 1633.2,
#  818: 1920.0,
#  819: 1962.0,
#  820: 2040.0,
#  821: 2076.0,
#  822: 2100.0,
#  823: 2449.2,
#  824: 2676.0,
#  825: 3024.0,
#  826: 3360.0,
#  827: 3390.0,
#  828: 3510.0,
#  829: 3660.0,
#  830: 4044.0,
#  831: 5092.8,
#  832: 5874.0,
#  833: 3705.6,
#  834: 3744.0,
#  835: 3840.0,
#  836: 4236.0,
#  837: 4344.0,
#  838: 4350.0,
#  839: 4680.0,
#  840: 4710.0,
#  841: 2820.0,
#  842: 2842.7999999999997,
#  843: 3354.0,
#  844: 3600.0,
#  845: 3660.0,
#  846: 4176.0,
#  847: 4176.0,
#  848: 4212.0,
#  849: 4860.0,
#  850: 5364.0,
#  851: 6552.0,
#  852: 6919.2,
#  853: 4544.4,
#  854: 4959.599999999999,
#  855: 5029.2,
#  856: 5308.8,
#  857: 5359.2,
#  858: 5451.599999999999,
#  859: 5796.0,
#  860: 6118.8,
#  861: 7370.4,
#  862: 2088.0,
#  863: 2136.0,
#  864: 2190.0,
#  865: 2622.0,
#  866: 2640.0,
#  867: 2670.0,
#  868: 2916.0,
#  869: 3210.0,
#  870: 3444.0,
#  871: 3450.0,
#  872: 4234.8,
#  873: 1585.2,
#  874: 1728.0,
#  875: 1794.0,
#  876: 1920.0,
#  877: 1926.0,
#  878: 2034.0,
#  879: 2100.0,
#  880: 2220.0,
#  881: 2340.0,
#  882: 2436.0,
#  883: 3192.0,
#  884: 2160.0,
#  885: 2778.0,
#  886: 3036.0,
#  887: 3810.0,
#  888: 2961.6,
#  889: 3096.0,
#  890: 3180.0,
#  891: 3372.0,
#  892: 3414.0,
#  893: 3718.7999999999997,
#  894: 5040.0,
#  895: 5250.0,
#  896: 5688.0,
#  897: 2160.0,
#  898: 2593.2,
#  899: 2604.0,
#  900: 2742.0,
#  901: 2796.0,
#  902: 2880.0,
#  903: 3810.0,
#  904: 4614.0,
#  905: 4707.599999999999,
#  906: 4800.0,
#  907: 3276.0,
#  908: 3288.0,
#  909: 3360.0,
#  910: 3594.0,
#  911: 3720.0,
#  912: 3762.0,
#  913: 3790.7999999999997,
#  914: 4284.0,
#  915: 4392.0,
#  916: 2148.0,
#  917: 2220.0,
#  918: 2236.7999999999997,
#  919: 2460.0,
#  920: 2496.0,
#  921: 3138.0,
#  922: 3150.0,
#  923: 3204.0,
#  924: 3314.4,
#  925: 3552.0,
#  926: 2280.0,
#  927: 2586.0,
#  928: 2625.6,
#  929: 2742.0,
#  930: 2856.0,
#  931: 3084.0,
#  932: 3690.0,
#  933: 3888.0,
#  934: 3952.7999999999997,
#  935: 5568.0,
#  936: 2406.0,
#  937: 2914.7999999999997,
#  938: 2914.7999999999997,
#  939: 3280.7999999999997,
#  940: 3600.0,
#  941: 2570.4,
#  942: 2779.2,
#  943: 3116.4,
#  944: 3116.4,
#  945: 3242.4,
#  946: 3408.0,
#  947: 3460.7999999999997,
#  948: 3608.4,
#  949: 3960.0,
#  950: 3997.2,
#  951: 4046.3999999999996,
#  952: 4264.8,
#  953: 1580.3999999999999,
#  954: 1695.6,
#  955: 1849.1999999999998,
#  956: 1914.0,
#  957: 1941.6,
#  958: 2127.6,
#  959: 2187.6,
#  960: 2250.0,
#  961: 2296.7999999999997,
#  962: 2389.2,
#  963: 2547.6,
#  964: 2724.0,
#  965: 2778.0,
#  966: 3220.7999999999997,
#  967: 3360.0,
#  968: 3376.7999999999997,
#  969: 3772.7999999999997,
#  970: 4292.4,
#  971: 5396.4,
#  972: 1120.8,
#  973: 1202.3999999999999,
#  974: 1574.3999999999999,
#  975: 1760.3999999999999,
#  976: 1777.2,
#  977: 1957.1999999999998,
#  978: 930.0,
#  979: 1093.2,
#  980: 1191.6,
#  981: 1202.3999999999999,
#  982: 1230.0,
#  983: 1300.8,
#  984: 1449.6,
#  985: 1512.0,
#  986: 1640.3999999999999,
#  987: 1722.0,
#  988: 1854.0,
#  989: 1858.8,
#  990: 1941.6,
#  991: 1968.0,
#  992: 968.4,
#  993: 984.0,
#  994: 1093.2,
#  995: 1120.8,
#  996: 1126.8,
#  997: 1300.8,
#  998: 1400.3999999999999,
#  999: 1453.2,
#  ...}

# %%
#Initialize bidValue parameter with the value of each bid 
model.bidValue = Param(model.BIDS, initialize = bidValues, doc='Value of each bid in the program')

# %%
#Create a dictionary of the total volume on each lane
demandValues = dict()
for lane in LanesDf.index:
    demandValues[lane] = 1

# %%
#Initialize demand parameter with the total volume on each lane (rep as demand/multiplicity)
model.demand = Param(model.LANES, initialize = demandValues, doc='Total demand on each lane')

# %%
#Create a dictionary of the gamma values
gamma = dict()
for lane in LanesDf.index:
    for bid in BidsDf.index:
        gamma[(lane,bid)] = gammaDf.loc[lane,bid]

# %%
#Initialize the gamma parameter
model.gamma = Param(model.LANES, model.BIDS, initialize=gamma, doc='gamma gives information regarding which bids are in a incumbent bids')

# %%
#Create a dictionary for the cardinality of each bid
cardinality = dict()
for bid in BidsDf.index:
    cardinality[bid] = gammaDf[bid].sum()
#cardinality

# %%
#Initialize the cardinality parameter
model.cardinality = Param(model.BIDS, initialize = cardinality, doc='Number of lanes in a bid package, |S_b|')

# %%
#Define the decision variable
model.x = Var(model.BIDS, domain = Binary, doc='Decision variable for each bid in the program')

# %%
#Objective minimizes the sum of x_b * v_b over all bids
def obj_expression(model):
    return sum(model.bidValue[i]*model.x[i] for i in model.BIDS)
model.OBJ = Objective(rule=obj_expression, sense=minimize, doc='Objective function definition')

# %%
#Define constraints

#def constraint_rule(model, l):
 #   return sum(model.delta[l,b]*model.x[b] for b in model.BIDS) <= 1
#model.xConstraint = Constraint(model.LANES, rule=constraint_rule)

def incumbent_constraint_rule(model, l):
    return sum(model.gamma[l,b]*model.x[b] for b in model.BIDS) <= 1
model.xConstraint = Constraint(model.LANES, rule=incumbent_constraint_rule)

def demand_constraint_rule(model):
    return sum(model.x[b]*model.cardinality[b] for b in model.BIDS) >= model.numItems
model.demandConstraint = Constraint(rule=demand_constraint_rule)

# %%
#Display of the output in order to retrieve and use in python
def pyomo_postprocess(options=None, instance=None, results=None):
    model.x.display()

# %%
#Run the model
from pyomo.opt import SolverFactory
import pyomo.environ
opt = SolverFactory("glpk")
# %timeit results = opt.solve(model)
# Out:
# 98.8 ms ± 6.42 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
results = opt.solve(model)
model.solutions.store_to(results)
print(results)
# Out:
# Problem:
# - Name: unknown
#   Lower bound: 737770.8
#   Upper bound: 737770.8
#   Number of objectives: 1
#   Number of constraints: 236
#   Number of variables: 2200
#   Number of nonzeros: 469
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.07663083076477051
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: optimal
#   Message: None
#   Objective:
#     OBJ:
#       Value: 737770.8000000003
#   Variable:
#     x[1007]:
#       Value: 1
#     x[1022]:
#       Value: 1
#     x[1032]:
#       Value: 1
#     x[1036]:
#       Value: 1
#     x[1050]:
#       Value: 1
#     x[1059]:
#       Value: 1
#     x[1072]:
#       Value: 1
#     x[1075]:
#       Value: 1
#     x[1082]:
#       Value: 1
#     x[108]:
#       Value: 1
#     x[1091]:
#       Value: 1
#     x[1100]:
#       Value: 1
#     x[1108]:
#       Value: 1
#     x[1122]:
#       Value: 1
#     x[1136]:
#       Value: 1
#     x[113]:
#       Value: 1
#     x[1143]:
#       Value: 1
#     x[1157]:
#       Value: 1
#     x[1171]:
#       Value: 1
#     x[1185]:
#       Value: 1
#     x[1195]:
#       Value: 1
#     x[11]:
#       Value: 1
#     x[1202]:
#       Value: 1
#     x[1213]:
#       Value: 1
#     x[1214]:
#       Value: 1
#     x[1220]:
#       Value: 1
#     x[1232]:
#       Value: 1
#     x[1240]:
#       Value: 1
#     x[1248]:
#       Value: 1
#     x[1255]:
#       Value: 1
#     x[1262]:
#       Value: 1
#     x[1269]:
#       Value: 1
#     x[1275]:
#       Value: 1
#     x[1284]:
#       Value: 1
#     x[1298]:
#       Value: 1
#     x[1311]:
#       Value: 1
#     x[1315]:
#       Value: 1
#     x[1319]:
#       Value: 1
#     x[131]:
#       Value: 1
#     x[1332]:
#       Value: 1
#     x[1342]:
#       Value: 1
#     x[1356]:
#       Value: 1
#     x[1372]:
#       Value: 1
#     x[1387]:
#       Value: 1
#     x[1397]:
#       Value: 1
#     x[139]:
#       Value: 1
#     x[1412]:
#       Value: 1
#     x[1419]:
#       Value: 1
#     x[1430]:
#       Value: 1
#     x[1434]:
#       Value: 1
#     x[1435]:
#       Value: 1
#     x[1439]:
#       Value: 1
#     x[1445]:
#       Value: 1
#     x[1449]:
#       Value: 1
#     x[1463]:
#       Value: 1
#     x[146]:
#       Value: 1
#     x[1470]:
#       Value: 1
#     x[1477]:
#       Value: 1
#     x[1490]:
#       Value: 1
#     x[1492]:
#       Value: 1
#     x[1503]:
#       Value: 1
#     x[1515]:
#       Value: 1
#     x[1518]:
#       Value: 1
#     x[1528]:
#       Value: 1
#     x[1539]:
#       Value: 1
#     x[1552]:
#       Value: 1
#     x[155]:
#       Value: 1
#     x[1562]:
#       Value: 1
#     x[1565]:
#       Value: 1
#     x[1577]:
#       Value: 1
#     x[1584]:
#       Value: 1
#     x[1593]:
#       Value: 1
#     x[1602]:
#       Value: 1
#     x[1615]:
#       Value: 1
#     x[1627]:
#       Value: 1
#     x[1640]:
#       Value: 1
#     x[1647]:
#       Value: 1
#     x[164]:
#       Value: 1
#     x[1659]:
#       Value: 1
#     x[1670]:
#       Value: 1
#     x[1683]:
#       Value: 1
#     x[1688]:
#       Value: 1
#     x[1701]:
#       Value: 1
#     x[1712]:
#       Value: 1
#     x[1722]:
#       Value: 1
#     x[1730]:
#       Value: 1
#     x[1741]:
#       Value: 1
#     x[1749]:
#       Value: 1
#     x[175]:
#       Value: 1
#     x[1763]:
#       Value: 1
#     x[1769]:
#       Value: 1
#     x[1783]:
#       Value: 1
#     x[1792]:
#       Value: 1
#     x[1799]:
#       Value: 1
#     x[1810]:
#       Value: 1
#     x[1817]:
#       Value: 1
#     x[1826]:
#       Value: 1
#     x[1834]:
#       Value: 1
#     x[1843]:
#       Value: 1
#     x[1854]:
#       Value: 1
#     x[1864]:
#       Value: 1
#     x[1878]:
#       Value: 1
#     x[1891]:
#       Value: 1
#     x[1900]:
#       Value: 1
#     x[1910]:
#       Value: 1
#     x[1921]:
#       Value: 1
#     x[192]:
#       Value: 1
#     x[1933]:
#       Value: 1
#     x[1940]:
#       Value: 1
#     x[1951]:
#       Value: 1
#     x[1965]:
#       Value: 1
#     x[1975]:
#       Value: 1
#     x[197]:
#       Value: 1
#     x[1984]:
#       Value: 1
#     x[1994]:
#       Value: 1
#     x[2006]:
#       Value: 1
#     x[2016]:
#       Value: 1
#     x[2026]:
#       Value: 1
#     x[2036]:
#       Value: 1
#     x[2048]:
#       Value: 1
#     x[2063]:
#       Value: 1
#     x[2070]:
#       Value: 1
#     x[2077]:
#       Value: 1
#     x[207]:
#       Value: 1
#     x[2091]:
#       Value: 1
#     x[2102]:
#       Value: 1
#     x[2108]:
#       Value: 1
#     x[2115]:
#       Value: 1
#     x[2122]:
#       Value: 1
#     x[2126]:
#       Value: 1
#     x[2137]:
#       Value: 1
#     x[2143]:
#       Value: 1
#     x[2145]:
#       Value: 1
#     x[2148]:
#       Value: 1
#     x[2151]:
#       Value: 1
#     x[2154]:
#       Value: 1
#     x[2160]:
#       Value: 1
#     x[2161]:
#       Value: 1
#     x[2166]:
#       Value: 1
#     x[2169]:
#       Value: 1
#     x[2174]:
#       Value: 1
#     x[2175]:
#       Value: 1
#     x[2177]:
#       Value: 1
#     x[2181]:
#       Value: 1
#     x[2182]:
#       Value: 1
#     x[2193]:
#       Value: 1
#     x[2197]:
#       Value: 1
#     x[225]:
#       Value: 1
#     x[232]:
#       Value: 1
#     x[248]:
#       Value: 1
#     x[253]:
#       Value: 1
#     x[25]:
#       Value: 1
#     x[261]:
#       Value: 1
#     x[272]:
#       Value: 1
#     x[285]:
#       Value: 1
#     x[294]:
#       Value: 1
#     x[2]:
#       Value: 1
#     x[305]:
#       Value: 1
#     x[321]:
#       Value: 1
#     x[337]:
#       Value: 1
#     x[33]:
#       Value: 1
#     x[348]:
#       Value: 1
#     x[363]:
#       Value: 1
#     x[371]:
#       Value: 1
#     x[384]:
#       Value: 1
#     x[38]:
#       Value: 1
#     x[391]:
#       Value: 1
#     x[403]:
#       Value: 1
#     x[410]:
#       Value: 1
#     x[417]:
#       Value: 1
#     x[427]:
#       Value: 1
#     x[442]:
#       Value: 1
#     x[452]:
#       Value: 1
#     x[463]:
#       Value: 1
#     x[469]:
#       Value: 1
#     x[483]:
#       Value: 1
#     x[495]:
#       Value: 1
#     x[49]:
#       Value: 1
#     x[512]:
#       Value: 1
#     x[527]:
#       Value: 1
#     x[537]:
#       Value: 1
#     x[554]:
#       Value: 1
#     x[565]:
#       Value: 1
#     x[577]:
#       Value: 1
#     x[581]:
#       Value: 1
#     x[595]:
#       Value: 1
#     x[598]:
#       Value: 1
#     x[59]:
#       Value: 1
#     x[613]:
#       Value: 1
#     x[624]:
#       Value: 1
#     x[632]:
#       Value: 1
#     x[644]:
#       Value: 1
#     x[650]:
#       Value: 1
#     x[662]:
#       Value: 1
#     x[670]:
#       Value: 1
#     x[685]:
#       Value: 1
#     x[692]:
#       Value: 1
#     x[701]:
#       Value: 1
#     x[714]:
#       Value: 1
#     x[717]:
#       Value: 1
#     x[71]:
#       Value: 1
#     x[722]:
#       Value: 1
#     x[728]:
#       Value: 1
#     x[736]:
#       Value: 1
#     x[750]:
#       Value: 1
#     x[760]:
#       Value: 1
#     x[770]:
#       Value: 1
#     x[775]:
#       Value: 1
#     x[786]:
#       Value: 1
#     x[794]:
#       Value: 1
#     x[807]:
#       Value: 1
#     x[817]:
#       Value: 1
#     x[828]:
#       Value: 1
#     x[833]:
#       Value: 1
#     x[841]:
#       Value: 1
#     x[852]:
#       Value: 1
#     x[858]:
#       Value: 1
#     x[866]:
#       Value: 1
#     x[86]:
#       Value: 1
#     x[875]:
#       Value: 1
#     x[885]:
#       Value: 1
#     x[892]:
#       Value: 1
#     x[897]:
#       Value: 1
#     x[910]:
#       Value: 1
#     x[918]:
#       Value: 1
#     x[929]:
#       Value: 1
#     x[940]:
#       Value: 1
#     x[946]:
#       Value: 1
#     x[958]:
#       Value: 1
#     x[968]:
#       Value: 1
#     x[973]:
#       Value: 1
#     x[978]:
#       Value: 1
#     x[97]:
#       Value: 1
#     x[996]:
#       Value: 1
#   Constraint: No values

# %%
#sends results to stdout
results.write()
print("\nDisplaying Solution\n" + '-'*60)
pyomo_postprocess(None, model, results)
# Out:
# WARNING: Some output was deleted.

# %%
model.pprint()
# Out:
# WARNING: Some output was deleted.

# %%
winningBids = []
index = 0
bidNum = 0
for bids in range(2199):
    if model.x[bids].value > 0:
        winningBids.append(bidNum)
    bidNum += 1
    index += 1

# %%
len(winningBids)
# Out:
# 234

# %%
winningBidsDf = BidsDf.iloc[winningBids]
winningBidsDf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bid</th>
#       <th>Carrier</th>
#       <th>Lot</th>
#       <th>Lot#</th>
#       <th>Cost</th>
#       <th>Rank</th>
#       <th>Lowest Bid</th>
#       <th>Delta vs Lowest</th>
#       <th># Shipments/Lot</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>VTGT@ISO_001</td>
#       <td>VTGT</td>
#       <td>ISO_001</td>
#       <td>1</td>
#       <td>3225.6</td>
#       <td>3</td>
#       <td>2864.4</td>
#       <td>361.2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>INTT@ISO_002</td>
#       <td>INTT</td>
#       <td>ISO_002</td>
#       <td>2</td>
#       <td>2337.6</td>
#       <td>1</td>
#       <td>2337.6</td>
#       <td>0.0</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>MSLO@ISO_003</td>
#       <td>MSLO</td>
#       <td>ISO_003</td>
#       <td>3</td>
#       <td>3558.0</td>
#       <td>4</td>
#       <td>2456.4</td>
#       <td>1101.6</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>MSLO@ISO_004</td>
#       <td>MSLO</td>
#       <td>ISO_004</td>
#       <td>4</td>
#       <td>2848.8</td>
#       <td>4</td>
#       <td>2214.0</td>
#       <td>634.8</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>BLKH@ISO_005</td>
#       <td>BLKH</td>
#       <td>ISO_005</td>
#       <td>5</td>
#       <td>2842.8</td>
#       <td>4</td>
#       <td>2143.2</td>
#       <td>699.6</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
Total = winningBidsDf['Cost'].sum()
Total
# Out:
# 737770.8

# %%
sum(winningBidsDf['Cost']*winningBidsDf['# Shipments/Lot'])
# Out:
# 11430865.2

# %%
winningBidsDf.to_csv('IncumbentWinningBids.csv')
